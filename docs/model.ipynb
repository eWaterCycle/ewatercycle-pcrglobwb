# %% [markdown]
# ![ewatercycle logo](https://raw.githubusercontent.com/eWaterCycle/ewatercycle/main/docs/examples/logo.png)
#
# # PCRGlobWB example use case
#
# This example shows how the [PCRGlobWB model](https://globalhydrology.nl/research/models/pcr-globwb-2-0/) can be used within the eWaterCycle system. It is based on the example use case from https://github.com/UU-Hydro/PCR-GLOBWB_input_example.
#
# This example use case assumes that the ewatercycle platform has been installed and configured on your system. See our [system setup documentation](https://ewatercycle.readthedocs.io/en/latest/system_setup.html) for instructions if this is not the case.

# %%
# This cell is only used to suppress some distracting output messages
import warnings

warnings.filterwarnings("ignore", category=UserWarning)

# %%
from pathlib import Path

import ewatercycle.forcing
import ewatercycle.models
import ewatercycle.parameter_sets
import matplotlib.pyplot as plt
from cartopy import crs
from cartopy import feature as cfeature
from rich import print

# %% [markdown]
# ## Loading a parameter set

# %% [markdown]
# A set of (example) parameter sets come pre-installed on the eWaterCycle system (see [system setup](https://ewatercycle.readthedocs.io/en/latest/system_setup.html) if this is not the case).

# %%
sets = ewatercycle.parameter_sets.available_parameter_sets()
sets.keys()
# Out:
# dict_keys(['lisflood_fraser', 'pcrglobwb_rhinemeuse_30min', 'wflow_rhine_sbm_nc', 'wflow_Rhine_ERA5-calibrated', 'wflow_Great-Kei_ERA5-calibrated', 'wflow_Doring_ERA5-calibrated', 'wflow_Merrimack_ERA5-calibrated', 'wflow_Meuse_ERA5-calibrated', 'wflow_rhine_ERA_Interim-calibrated', 'wflow_Savannah_ERA-Interim-calibrated', 'wflow_Great-Kei_ERA_Interim-calibrated', 'wflow_Merrimack_ERA_Interim-calibrated', 'wflow_Meuse_ERA_Interim-calibrated', 'lisflood_global-masked_01degree', 'pcrglobwb_merrimack_05min', 'pcrglobwb_rhine_05min', 'wflow_merrimack_techpaper', 'wflow_humber', 'sfincs_humber'])

# %% [markdown]
# Existing parametersets can easily be loaded:

# %%
# TODO version 1 setters, redundant now
parameter_set = sets["pcrglobwb_rhinemeuse_30min"]
print(parameter_set)

# version 2
ini = Path(
    "/data/shared/parameter-sets/pcrglobwb_rhinemeuse_30min/setup_natural_test.ini"
)
pcr_glob_directory = Path("/data/shared/parameter-sets/pcrglobwb_rhinemeuse_30min")

parameter_set = ewatercycle.parameter_sets.ParameterSet(
    name="custom_parameter_set",
    directory=pcr_glob_directory,
    config=ini,
    target_model="pcrglobwb",
    supported_model_versions={"v0.2.3"},
)

print(parameter_set)
# Out:
# ParameterSet(
#     name='pcrglobwb_rhinemeuse_30min',
#     directory=PosixPath('/data/shared/parameter-sets/pcrglobwb_rhinemeuse_30min'),
#     config=PosixPath('/data/shared/parameter-sets/pcrglobwb_rhinemeuse_30min/setup_natural_test.ini'),
#     doi='https://doi.org/10.5281/zenodo.1045339',
#     target_model='pcrglobwb',
#     supported_model_versions={'setters'},
#     downloader=None
# )
# ParameterSet(
#     name='custom_parameter_set',
#     directory=PosixPath('/data/shared/parameter-sets/pcrglobwb_rhinemeuse_30min'),
#     config=PosixPath('/data/shared/parameter-sets/pcrglobwb_rhinemeuse_30min/setup_natural_test.ini'),
#     doi='N/A',
#     target_model='pcrglobwb',
#     supported_model_versions={'v0.2.3'},
#     downloader=None
# )

# %% [markdown]
# It is also possible to load a custom parameterset by passing in the relevant parameters directly:
#
# ```py
# custom_parameter_set = ewatercycle.parameter_sets.ParameterSet(
#     name="custom_parameter_set",
#     directory="/path-to-params/pcrglobwb_rhinemeuse_30min",
#     config="/path-to-params/pcrglobwb_rhinemeuse_30min/setup_natural_test.ini",
#     target_model="pcrglobwb",
#     supported_model_versions={"setters"},
# )
# ```

# %% [markdown]
# ## Load forcing data
#
# For this example case, the forcing is already included in the parameter set and configured correctly. Therefore in principle this step can be skipped. However, for the purpose of illustration, we show how the forcing would be loaded using the `ewatercycle.forcing` module, as if it came from another source. To learn about forcing generation, see our [preprocessing examples](https://ewatercycle.readthedocs.io/en/latest/examples/generate_forcing.html).

# %%
forcing = ewatercycle.forcing.sources["PCRGlobWBForcing"](
    start_time="2001-01-01T00:00:00Z",
    end_time="2010-12-31T00:00:00Z",
    directory=parameter_set.directory / "forcing",
    shape=None,  # if available, it can be used e.g. for plotting
    precipitationNC="precipitation_2001to2010.nc",
    temperatureNC="temperature_2001to2010.nc",
)
print(forcing)
# Out:
# PCRGlobWBForcing(
#     start_time='2001-01-01T00:00:00Z',
#     end_time='2010-12-31T00:00:00Z',
#     directory=PosixPath('/data/shared/parameter-sets/pcrglobwb_rhinemeuse_30min/forcing'),
#     shape=None,
#     filenames={},
#     precipitationNC='precipitation_2001to2010.nc',
#     temperatureNC='temperature_2001to2010.nc'
# )

# %% [markdown]
# ## Setting up the model
#
# Note that the model version and the parameterset versions should be compatible.

# %%
pcrglob = ewatercycle.models.PCRGlobWB(parameter_set=parameter_set, forcing=forcing)
print(pcrglob)
# Out:
# PCRGlobWB(
#     parameter_set=ParameterSet(
#         name='custom_parameter_set',
#         directory=PosixPath('/data/shared/parameter-sets/pcrglobwb_rhinemeuse_30min'),
#         config=PosixPath('/data/shared/parameter-sets/pcrglobwb_rhinemeuse_30min/setup_natural_test.ini'),
#         doi='N/A',
#         target_model='pcrglobwb',
#         supported_model_versions={'v0.2.3'},
#         downloader=None
#     ),
#     forcing=PCRGlobWBForcing(
#         start_time='2001-01-01T00:00:00Z',
#         end_time='2010-12-31T00:00:00Z',
#         directory=PosixPath('/data/shared/parameter-sets/pcrglobwb_rhinemeuse_30min/forcing'),
#         shape=None,
#         filenames={},
#         precipitationNC='precipitation_2001to2010.nc',
#         temperatureNC='temperature_2001to2010.nc'
#     )
# )

# %%
pcrglob.version
# Out:
# 'v0.2.3'

# %% [markdown]
# eWaterCycle exposes a selected set of configurable parameters. These can be modified in the `setup()` method.

# %%
print(pcrglob.parameters)
# Out:
# dict_items([('start_time', '2001-01-01T00:00:00Z'), ('end_time', '2001-01-01T00:00:00Z'), ('routing_method',
# 'accuTravelTime'), ('max_spinups_in_years', '20')])

# %% [markdown]
# Calling `setup()` will start up a container. Be careful with calling it multiple times!

# %%
cfg_file, cfg_dir = pcrglob.setup(
    end_time="2001-02-28T00:00:00Z", max_spinups_in_years=5
)
cfg_file, cfg_dir
# Out:
# ('/home/mmelotto/ewatercycle-pcrglobwb/docs/pcrglobwb_20260924_072503/pcrglobwb_ewatercycle.ini',
#  '/home/mmelotto/ewatercycle-pcrglobwb/docs/pcrglobwb_20260924_072503')

# %%
pcrglob.parameters
# Out:
# dict_items([('start_time', '2001-01-01T00:00:00Z'), ('end_time', '2001-02-28T00:00:00Z'), ('routing_method', 'accuTravelTime'), ('max_spinups_in_years', '5')])

# %% [markdown]
# Note that the parameters have been changed. A new config file which incorporates these updated parameters has been generated as well. If you want to see or modify any additional model settings, you can acces this file directly. When you're ready, pass the path to the config file to `initialize()`.

# %%
pcrglob.initialize(cfg_file)

# %% [markdown]
# ## Running the model
#
# Simply running the model from start to end is straightforward. At each time step we can retrieve information from the model.

# %%
while pcrglob.time < pcrglob.end_time:
    pcrglob.update()

# %% [markdown]
# ## Interacting with the model

# %% [markdown]
# PCRGlobWB exposes many variables. Just a few of them are shown here:

# %%
list(pcrglob.output_var_names)
# Out:
# ['land_surface_evaporation',
#  'precipitation',
#  'temperature',
#  'reference_potential_evaporation',
#  'land_surface_potential_evaporation',
#  'land_surface_actual_evaporation',
#  'land_surface_evaporation_fraction',
#  'interception_storage',
#  'snow_water_equivalent',
#  'snow_free_water',
#  'top_water_layer',
#  'upper_soil_storage',
#  'lower_soil_storage',
#  'interception_evaporation',
#  'snow_free_water_evaporation',
#  'top_water_layer_evaporation',
#  'bare_soil_evaporation',
#  'total_transpiration',
#  'upper_soil_transpiration',
#  'lower_soil_transpiration',
#  'direct_runoff',
#  'interflow',
#  'baseflow',
#  'infiltration',
#  'groundwater_recharge',
#  'groundwater_capillary_rise',
#  'total_groundwater_recharge',
#  'irrigation_gross_demand',
#  'irrigation_gross_demand_volume',
#  'non_irrigation_gross_demand',
#  'non_irrigation_gross_demand_volume',
#  'total_gross_demand',
#  'total_gross_demand_volume',
#  'upper_soil_saturation_degree',
#  'lower_soil_saturation_degree',
#  'soil_saturation_degree_for_the_entire_soil_layers',
#  'groundwater_storage',
#  'fossil_groundwater_storage',
#  'total_groundwater_storage',
#  'surface_water_abstraction',
#  'surface_water_abstraction_volume',
#  'non_fossil_groundwater_abstraction',
#  'fossil_groundwater_abstraction',
#  'total_groundwater_abstraction',
#  'total_groundwater_abstraction_volume',
#  'desalination_source_abstraction',
#  'desalination_source_abstraction_volume',
#  'total_abstraction',
#  'fraction_of_surface_water_allocation',
#  'fraction_of_non_fossil_groundwater_allocation',
#  'fraction_of_other_water_source_allocation',
#  'fraction_of_desalinated_water_allocation',
#  'total_fraction_water_allocation',
#  'water_body_actual_evaporation',
#  'water_body_potential_evaporation',
#  'water_body_evaporation_fraction',
#  'total_evaporation',
#  'total_potential_evaporation',
#  'total_evaporation_fraction',
#  'land_surface_runoff',
#  'accumulated_land_surface_baseflow',
#  'discharge',
#  'total_runoff',
#  'local_water_body_flux',
#  'net_liquid_water_to_soil',
#  'total_thickness_of_active_water_storage',
#  'total_thickness_of_water_storage',
#  'total_volume_of_water_storage',
#  'surface_water_storage',
#  'lake_and_reservoir_storage',
#  'channel_storage',
#  'snow_melt',
#  'consumptive_water_use_for_non_irrigation_demand',
#  'return_flow_from_non_irrigation_demand_withdrawal',
#  'fraction_of_surface_water',
#  'totalPotentialMaximumGrossDemand',
#  'return_flow_from_groundwater_abstraction',
#  'surface_water_infiltration',
#  'transpiration_from_irrigation',
#  'surface_water_level',
#  'paddy_irrigation_withdrawal',
#  'non_paddy_irrigation_withdrawal',
#  'irrigation_withdrawal',
#  'domestic_water_withdrawal',
#  'industry_water_withdrawal',
#  'livestock_water_withdrawal',
#  'domesticWaterWithdrawalVolume',
#  'industryWaterWithdrawalVolume',
#  'livestockWaterWithdrawalVolume',
#  'irrigationWaterWithdrawalVolume',
#  'domesticWaterConsumptionVolume',
#  'industryWaterConsumptionVolume',
#  'livestockWaterConsumptionVolume',
#  'precipitation_at_irrigation',
#  'evaporation_from_irrigation',
#  'netLqWaterToSoil_at_irrigation',
#  'transpiration_from_irrigation',
#  'precipitation_at_irrigation_volume',
#  'evaporation_from_irrigation_volume',
#  'netLqWaterToSoil_at_irrigation_volume',
#  'transpiration_from_irrigation_volume',
#  'lake_and_reservoir_inflow',
#  'Precip',
#  'Evap',
#  'Runoff',
#  'Qs',
#  'Qsb',
#  'Qsm',
#  'PotEvap',
#  'ECanop',
#  'TVeg',
#  'ESoil',
#  'EWater',
#  'RivOut',
#  'SWE',
#  'SWE',
#  'SurfStor',
#  'SurfMoist',
#  'RootMoist',
#  'GroundMoist',
#  'TotMoist',
#  'Tsurf',
#  'P',
#  'ET',
#  'SWE',
#  'SWE_excluding_free_water',
#  'Qsm',
#  'SM',
#  'Qr',
#  'Q',
#  'snowFraction',
#  'UppSM',
#  'LowSM',
#  'RefPET',
#  'CropPET',
#  'TWS']

# %% [markdown]
# Model fields can be fetched as xarray objects (or as flat numpy arrays using `get_value()`):

# %%
da = pcrglob.get_value_as_xarray("discharge")
# da.thin(5)  # only show every 5th value in each dim

# %% [markdown]
# Xarray makes it very easy to plot the data. In the figure below, we add three points that we will use to illustrate that we can also access individual grid cells.

# %%
fig = plt.figure(dpi=120)
ax = fig.add_subplot(111, projection=crs.PlateCarree())
da.plot(ax=ax, cmap="GnBu")

# Overlay ocean and coastines
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.RIVERS, color="k")
ax.coastlines()

# Add some verification points
target_longitudes = [7.8, 10.2, 11]
target_latitudes = [50.3, 49.8, 47]
ax.scatter(target_longitudes, target_latitudes, s=250, c="r", marker="x", lw=2)

# %% [markdown]
# We can get (or set) the values at custom points as well:

# %%
pcrglob.get_value_at_coords("discharge", lon=target_longitudes, lat=target_latitudes)
# Out:
# array([714.34155273,  84.78503418,          nan])

# %% [markdown]
# ## Cleaning up
#
# Models usually perform some "wrap up tasks" at the end of a model run, such as writing the last outputs to disk and releasing memory. In the case of eWaterCycle, another important teardown task is destroying the container in which the model was running. This can free up a lot of resources on your system. Therefore it is good practice to always call `finalize()` when you're done with an experiment.

# %%
pcrglob.finalize()
